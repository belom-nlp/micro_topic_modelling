# %% [markdown]
# <a href="https://colab.research.google.com/github/belom-nlp/micro_topic_modelling/blob/main/notebooks/fetch20_MTM_BERTopic_Top2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Installing MTM

# %%
! pip install sentence_transformers
! pip install transformers

# %%
#importing necessary libraries
from collections import Counter
import numpy as np
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
import nltk
import torch

from sentence_transformers import SentenceTransformer

from sklearn.decomposition import PCA
from sklearn.cluster import HDBSCAN, DBSCAN, KMeans
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import matplotlib.pyplot as plt

# %%
nltk.download('punkt')
nltk.download('stopwords')

# %%
import random

def set_random_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

set_random_seed(42)

# %%
from model import MicroTopicModeller

# %% [markdown]
# #Importing fetch20 Dataset

# %%
from sklearn.datasets import fetch_20newsgroups

# %%
ds = fetch_20newsgroups()

# %%
mtm = MicroTopicModeller(use_pca=True, use_cuda=True)

# %%
topic_words = mtm.pipeline(ds.data)

# %%
for key in topic_words.keys():
    print(key, ', '.join(topic_words[key]))
# Out:
# topic0 god, ax, b8f, use, program, a86, max, gun, space, file, organization, article, people, 145, writes, year, windows
# topic1 armenians, armenian, years, scsi, russian, organization, people, reserve, marine, insurance, year, naval, car
# topic2 values, ax, center, b8f, information, v2, nasa, dseg, stanford, a86, max, 16, house, space, research, leland, dam9543, david, g9v, ti, gillow, forsythe
# topic3 rsaref, mobility, mpce, nec, behanna, johnh, key, world, cross, deep, implementation, astemizole, bmw, ncsc, bolt, nsa, right, speculation, really, tools, said
# topic4 il, bike, thinking, huji, atheists, eavesdropper, cfj, hernlem, adam, mia, new, cs, q30tbxn, amos, jason, good, charitable, steel
# topic5 accel, key, 960, fleury, reverse, schism, chip, hernlem, space, mia, color, c5rpoj, excommunicated, outlet, 200mb, trsvax, turmeric, charitable, yardley, w165w, group
# topic6 bbs, accel, roger, manes, cfj, better, keenan, linknet, hernlem, numbers, mia, magpie, gl, 200mb, pace, charitable, arthur, qed, yardley, piece
# topic7 oryx, calpoly, jerry, topology, user, bikes, just, image, sun, processing, cola, matt, insurance, mitel, warrant, synoptics, reeds, expect, mishra, discount, koresh, greg
# topic8 scsi, se, rose, food, nextwork, printf, sun, hulman, output, pet, msg, oname, maine, posting, hernlem, accelerator, file, daubendr, entry, group
# topic9 division, names, protected, believe, key, imat, game, compound, war, seahunt, c5rpoj, article, people, sawed, course, nelson, miller, stratus
# topic10 itd, christian, umich, accel, btr, sean, leadership, like, canterbury, sweda, id, zealand, posting, drive, hernlem, auspex, kf, 200mb, insights, disk, css, yardley
# topic11 blindly, hurt, question, average, ram, extra, stolen, follow, authority, dcon, hits, organization, c5rpoj, lotto, dops, pixie, swerve, fielder, countersteering, study, w165w
# topic12 orioles, yardley, tu, 1993apr13, olivetti, accel, moral, ordinary, cv, language, 22, hernlem, don, animals, objective, mia, organization, kf, right, 200mb, charitable, insights
# topic13 lord, father, yardley, umr, accel, race, mark, saint, want, victims, gonzaga, rutgers, space, tom, romulus, netcom, sides, aloysius, kf, kaldis, 200mb, help, buzz, insights
# topic14 channel, higgins, sandvik, busmastering, level, apple, dma, xfers, ignorance, gov, killing, hernlem, fnal, mia, wrong, isa, team, kent, know, charitable, group
# topic35 imake, cpp, 00, expo, 800, bike, ma, start, use, directive, derienzo, low, tyngsboro, potassium, harvard, new, garnet, motorola, berkeley, rind, babies, joel
# topic36 p7, engine, 00, eliezer, bbs, lars, cutting, physics, started, spect, napalm, clinton, hernlem, tx, mia, components, jorgensen, atf, david, ford, charitable, ha, syntax, amp
# topic37 uwa, valentine, centerline, use, sun, sensor, dv, organisation, added, au, stanford, posting, oz, light, hawks, used, expensive, ac, scott, windows, car
# topic38 head, sandvik, model, image, apple, kin, free, 24, 022, grand, shell, isi, 047, hernlem, data, visual, mia, accept, princeton, liner, helmet, impact, charitable
# topic39 lord, joshua, mobility, dsd, umr, dma, contradicts, christ, evans, black, eskimo, alternatives, sabbath, delivered, freemasonry, edge, leather, utexas, know, sword, toleration, page
# topic40 bike, 03, need, willner, use, 05, insurance, israeli, adobe, humphreys, 16, file, article, ibm, car, live, 2x, gregh, baldwa, dsu, pentium
# topic41 accel, better, su, er1, eridan, tony, cleveland, chuvashia, organization, 200mb, captain, rosicrucian, blurb, alomar, insights, competing, yardley
# topic42 income, ns1, court, just, boots, internet, fleury, boot, box, reboost, lehigh, tax, don, c5rpoj, store, car, henry, hst, turmeric, bellcore, w165w
# topic43 lord, god, values, quicktime, muller, version, just, cpu, dos, ___, indiana, card, new, vs, does, copies, duo, point, disks, windows
# topic44 god, yardley, christian, windows, accel, box, israel, ndis, zbib, excited, does, academic, land, load, 200mb, arabs, convince, really, jews, cubs, insights, real
# topic45 org, god, armenian, bradley, ermeni, water, cfj, israel, speedstar, lyme, victims, hernlem, mia, infantile, nysernet, article, __, isa, astein, charitable, genocide, group
# topic46 socrates, years, space, jamal, new, set, believe, arrogance, graphics, word, arrogant, telescope, sgi, national, satellite, university, truth
# topic47 minyos, chen, kit, food, upgrade, people, good, computer, noise, told, iintx, adc, causes, inflammation, msg, xx, crohn
# topic48 polygon, armenian, oberto, electric, argic, nazi, fleury, webb, problem, armenians, hernlem, don, nazis, grasp, routine, c5rpoj, jesus, turmeric, impact, body, fields, w165w
# topic49 select, se, sandvik, image, available, christ, anti, grayscale, print, data, gun, vacation, ftp, wright, jesus, media, jews, stratus
# topic50 mormons, navy, loopback, 07, apple, connector, bus, grapevine, grape, secular, did, nswses, days, vs, threat, edge, netcom, ca, lefty, authorities, cubs, better, serial
# topic51 god, revelation, don, morality, weapons, select, prayers, think, jesus, local, like, say, heavy, koresh, militia, xerox
# topic52 christians, god, bby, yardley, experience, accel, believe, cfj, gregory, knox, hernlem, morality, objective, mia, melbourne, does, kf, fake, 200mb, pace, really, say, charitable, insights
# topic53 00, hernlem, witch, gospels, cover, hard, mia, following, win, series, physics, team, writes, 22, molecular
# topic54 copper, reason, cipriani, god, yardley, zinc, just, modems, accel, fleury, gtoal, physical, senses, c5rpoj, crypto, kf, approved, evidence, 200mb, acid, disk, insights, w165w
# topic55 john, resume, 00, behunin, munch, letter, larger, microsoft, fasad, elee, jmunch, custom, hernlem, hertz, swap, mia, __, hockey, sunday, games, disk, windows, shatim
# topic56 anon, president, duffey, american, sure, people, served, anonymity, posting, service, writes, anonymous, university, ncr
# topic57 ssrt, yardley, accel, rational, cfj, science, fleury, program, didn, hernlem, space, technology, mia, new, c5rpoj, kf, 200mb, work, fulk, charitable, insights, w165w
# topic58 expansion, christians, navy, se, christian, charitable, mil, graphics, cfj, sgi, like, trait, folks, hernlem, years, chalmers, mia, net, maf, hp, sales, dtek
# topic59 pgh, turks, lemieux, ethnic, greek, cfj, protestants, greece, la, hernlem, mia, think, njd, jim, charitable, early, roughing, church
# topic60 clp, oberto, genes, chuck, geb, gordon, benjamin, csb1, rights, ncr, mcmath, spot, colorado, persons, gov, clinton, atlantaga, wilson, marc, pitt, blood, icgeb, files
# topic61 qazi, mobility, eavesdropper, kratz, pjs269, contradicts, stolen, uwm, alternatives, posting, hernlem, convertible, gun, mia, safety, q30tbxn, jester, disks, steel, ridiculously, 365
# topic62 ted, play, hernlem, space, pittsburgh, organization, article, abc, course, cs, power, colorado, like, programming, april
# topic63 int, scsi, yardley, cmort, doctor, accel, nasa, ultrasound, wchar_t, public, xsi, c5rpoj, solutions, __, kf, character, 200mb, hp, disk, lumpkin, read, insights
# topic64 radio, org, zone, ng, mitre, archbishop, cfj, like, legal, posting, schism, umbc, canon, hernlem, judge, access, mia, majority, pace, banz, charitable, schismatic, church
# topic65 det, mancus, cal, bos, computer, lh, illinois, gov, virginia, alfa, file, vs, uiuc, spider, pitt, cs, 000, daughter, time
# topic66 god, children, drivers, printer, nmti, drieux, respect, dma, stephen, know, government, like, writes, motherboard, eisa, semi, posting
# topic67 org, 00, god, washington, odometer, schwarz, accel, mitre, schwarze, reading, zoroastrianism, caltech, ce, freedom, new, glover, iranian, 200mb, 20, magi, really, april, car
# topic68 come, umcc, 130, example, umich, weimar, austin, lehr, true, daystar, hernlem, don, gun, mia, guns, ux, pov, jesus, 30, ibm
# topic69 mike, virtual, uswest, reality, com3, ge, flame, irq5, hernlem, far, advtech, convex, clothing, ma90jjw, interrupt, hp, writes, deskjet
# topic70 celestial, vms, mu, yardley, men, tempest, just, accel, cmu, gen, vinyl, wilson, compiles, andrew, characters, kf, sun4_411, csd, 200mb, hats, insights
# topic71 god, aem, star, trek, bj, computer, bmug, like, peter, card, equip, mb, batf, cache, used, bosnia, hp, point, deskjet, ibm
# topic72 pictures, miles, revelation, writes, csie, powerpc, article, good, san, zisfein, aura, jim, ntu, high, neurologic, ruu
# topic73 case, yardley, coyote, zip, accel, date, directory, levine, wpi, black, people, ghostscript, think, null, jesus, african, 200mb, widget, defaria, ching, insights, files
# topic74 keith, goals, accel, like, w4wg, natural, hernlem, mia, does, tansu, think, 200mb, nyx, insights, ford, windows, yardley, car
# topic75 fbi, noaa, 00, window, niguma, 1971, information, copy, schaefer, accident, says, hernlem, mia, server, tih, set, roby, protection, 000, bear, naren, imag
# topic182 john, polio, guy, utica, organization, encryption, people, gm, st, like, university
# topic183 uniforms, rsa, public, compariators, article, need, circuit, verity, barry, key, screen, ripem, adobe, transistor, pgp, berkeley
# topic184 mycal, megs, yardley, ram, accel, cfj, simms, posting, drive, hernlem, left, mia, bob, organization, right, kf, 200mb, mcguire, charitable, insights, group
# topic185 00, long, s1, cd, mahan, brand, lazarus, ann, posting, asking, don, organization, shipping, monash, ed, david, tgv, 10
# topic186 crypt, reagan, sci, apple, sex, fpu, ahl, 040, yeast, research, uiuc, configuration, article, does, cso, writes
# topic187 don, shoei, cramer, optilink, just, version, mouse, hallam, sun, export, selfish, available, xterm, tar, motif, writes, contrib
# topic188 god, umcc, mike, ax, b8f, nazi, just, scripture, max, mks, 2di, don, organization, 145, homes, know
# topic189 goal, don, karplus, mind, converter, organization, netcom, errors, howard, logic, sgi, know, livesey, high, throttle
# topic190 fragante, ger, stephanopoulos, postscript, mask, card, mr, don, president, bob, hockey, gainey, ca, dal, unixg, know, bnr, winjet, video, greg, files
# topic191 window, waste, god, netherlands, aruit, cfj, entire, language, blah, hernlem, mia, uiuc, __, uidaho, cs, cso, coe, ruiter, charitable, ha, spirit, truth
# topic192 line, detroit, accel, dma, leafs, key, bus, audio, ___, drive, wings, chip, article, clipper, __, pc, 200mb, ____, anderson, bit, serial
# topic193 god, assault, wisdom, rights, oil, cfj, rogers, iran, hernlem, bible, mia, organization, overturn, state, nc, jesus, hp, charitable, spirit, group
# topic194 scs, scsi, baseball, duke, believe, s1, university, software, posting, lilac, statements, cache, organization, newton, portal, bit, s2
# topic195 chip, mac, scsi, 32, passat, purchased, windows, 92, vw, world, quality, os, bit, market, car
# topic196 long, yardley, accel, ll, sean, fleury, cfj, canterbury, hernlem, mia, c5rpoj, article, pistons, clipper, 256, kf, looking, 200mb, pace, turmeric, charitable, insights, w165w
# topic197 writes, 00, hamilton, michael, average, wynapse, inflation, 80, modem, bs, td, nicho, plan, sg, rd, ibm, 000, 20, pin, clubbing
# topic198 00, scsi, yardley, articles, context, midi, accel, floppy, drive, play, 50, mb, ide, weiss, 200mb, white, jim, shalala, windows, insights, files
# topic199 sammons, ece, yardley, sandvik, lance, accel, motif, hobo, chip, turkey, colostate, arromdee, clipper, orst, drum, absolute, cs, 200mb, linux, writes, insights
# topic200 hannover, graphic_display, bible, god, sniper, peace, organization, article, people, pfuetzner, board, matthias, israel, mother, card
# topic201 compaq, ram, country, mjp, tool, caesar, like, israel, lose, gilham, mpw, didn, jesper, ps, gazans, portal, lethal, spring, agrep, gaza, king, ibm
# topic202 window, yardley, expose, sexy, accel, lee, autobahn, morgan, posting, don, hernlem, tony, europe, new, article, right, kf, 200mb, alec, du, insights
# topic203 god, purdue, bike, frank, hell, deficit, beckman, hydro, believe, israel, gov, des, judge, egalon, economic, lebanese, article, does, course, countersteering, writes
# topic204 100, forsale, washington, nations, ncsl, rwing, atmos, colorado, cfj, boulder, 250, nist, gov, archiving, hernlem, mia, yuri, russia, charitable
# topic226 se, just, pp, game, like, mark, program, 11, shots, rules, entry, demers, period, article, info, entries, ucsd, allerton, atlastele, uk, 30, irq, 10
# topic227 yardley, kirk, darling, greek, accel, angels, minority, greece, posting, turkey, ubc, gun, oh, pollux, rick, kf, ca, clementine, 200mb, hays, turkish, insights
# topic228 american, darling, key, norway, like, arens, crimes, gun, toshiba, cleveland, amdahl, middle, guns, does, cellar, laptop
# topic229 cost, bike, ama, image, just, rights, rajiev, centre, years, tube, article, calspan, gainey, ca, think, hallam, corn, screen, phill, bnr, pluggers
# topic230 window, reston, toronto, values, allen, event, information, nasa, science, motif, marriage, university, virginia, people, married, evidence, games, truth
# topic231 composite, overreacting, geb, 960, multimedia, fleury, banks, digex, don, access, tom, new, c5rpoj, migraines, pitt, young, steve, think, jack, turmeric, know, year, w165w
# topic232 center, uart, cryptosystem, accel, key, world, plaintext, like, israel, wpi, gaza, bits, hercules, mcmaster, 200mb, detect, p_1, attack, 8051, irq, group
# topic233 rpi, mathcad, detroit, ram, optilink, port, main, university, cramer, did, access, swap, file, value, ps, state, know, tanks, professors, point, windows
# topic234 unc, james, clarkson, christian, faith, included, 960, oit, like, fleury, detectors, westminster, c5rpoj, gibbs, best, offer, turmeric, know, radley, tuinstra, w165w
# topic235 budget, argic, reagan, economy, suits, israel, la, don, pt, organization, encore, pts, rudman, bush, azeri, piece
# common_key_words com, edu, subject, lines

# %%
topics = []
for k, j in topic_words.items():
    if k != 'common_key_words':
        topics.append(j)

# %% [markdown]
# #Metrics

# %% [markdown]
# See MTM_on_train_datasets.ipynb notebook for the explanation.

# %%
! git clone https://github.com/christianrfg/tm_metrics.git
# Out:
# Cloning into 'tm_metrics'...
# remote: Enumerating objects: 79, done.
# remote: Total 79 (delta 0), reused 0 (delta 0), pack-reused 79
# Receiving objects: 100% (79/79), 1.19 MiB | 10.96 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# !sed -i 's/cv_model.get_feature_names()/cv_model.get_feature_names_out()/' tm_metrics/tm_metrics/feature_extraction/text.py

# %%
# !pip install -U /content/tm_metrics
# Out:
# Processing ./tm_metrics
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: tm-metrics
#   Building wheel for tm-metrics (setup.py) ... done
#   Created wheel for tm-metrics: filename=tm_metrics-0.1-py3-none-any.whl size=8201 sha256=d1612d940b7a04804593abb12bdfa2a7978593d46b49716a4d228a5a25ae7f8e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j9awrp2q/wheels/88/73/88/e84eb7e10e9fc6ecb2f0e636d851f394cd8789c1ed40d09cc7
# Successfully built tm-metrics
# Installing collected packages: tm-metrics
# Successfully installed tm-metrics-0.1

# %%
def pmi(topic_words, word_frequency, word_frequency_in_documents, n_docs, normalise=False):
    """PMI/NPMI topic quality metric for a topic.

    Calculates the PMI/NPMI topic quality metric for one individual topic based on the topic words.

    Args:
        topic_words: list
            Words that compose one individual topic.
        word_frequency: dict
            Frequency of each word in corpus.
        word_frequency_in_documents: dict
            Frequency of each word for each document in corpus.
        n_docs: int
            Number of documents in the corpus.
        normalise: bool, default=False
            Where to normalise (NPMI) or not (PMI).

    Returns:
        pmi: float
            Resultant PMI metric value for the topic.
        npmi: float
            Resultant NPMI metric value for the topic.
    """
    n_top = len(topic_words)
    pmi = 0.0
    npmi = 0.0

    for j in range(1, n_top):
        for i in range(0, j):
            ti = topic_words[i]
            tj = topic_words[j]

            c_i = word_frequency[ti]
            c_j = word_frequency[tj]
            c_i_and_j = len(word_frequency_in_documents[ti].intersection(word_frequency_in_documents[tj]))

            dividend = (c_i_and_j + 1.0) / float(n_docs)
            divisor = ((c_i * c_j) / float(n_docs) ** 2)
            pmi += max([np.log(dividend / divisor), 0])

            npmi += -1.0 * np.log((c_i_and_j + 0.01) / float(n_docs))

    if npmi != 0:
        npmi = pmi / npmi

    if normalise:
        return npmi
    else:
        return pmi

# %%
from tm_metrics.feature_extraction import get_tfidf_matrices, get_vocabulary, get_word_frequencies
from tm_metrics.metrics import coherence, tfidf_coherence, lcp, topic_w2v

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from gensim.models import Word2Vec

# %%
def prepare_data_for_metrics(data):
  n_features = int(len(data)/2)
  tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english', max_features=1000)
  tfidf = tfidf_vectorizer.fit_transform(data)
  tfidf_feature_names = tfidf_vectorizer.get_feature_names_out()
  vocabulary = get_vocabulary(data)
  word_frequency, word_frequency_in_documents = get_word_frequencies(data)
  return word_frequency, word_frequency_in_documents

# %% [markdown]
# Preparing data for metrics:

# %%
wf, wfid = prepare_data_for_metrics(ds.data)

# %%
def count_metrics(x, word_frequency, word_frequency_in_documents):

    pmi_results = []
    npmi_results = []
    coherence_results = []


    n_samples=len(x)

    for tw in x:
        pmi_ = pmi(tw, word_frequency, word_frequency_in_documents, n_samples, normalise=False)
        npmi_ = pmi(tw, word_frequency, word_frequency_in_documents, n_samples, normalise=True)

        coherence_ = coherence(tw, word_frequency, word_frequency_in_documents)


        pmi_results.append(pmi_)
        npmi_results.append(npmi_)
        coherence_results.append(coherence_)

    return {'pmi_results': pmi_results,
          'npmi_results': npmi_results,
          'coherence_results': coherence_results}

# %%
results = count_metrics(topics, wf, wfid)

# %%
def get_result_table(d):
  pmi_results = d['pmi_results']
  npmi_results = d['npmi_results']
  coherence_results = d['coherence_results']


  avg_pmi, std_pmi = np.mean(pmi_results), np.std(pmi_results)
  avg_npmi, std_npmi = np.mean(npmi_results), np.std(npmi_results)
  avg_coherence, std_coherence = np.mean(coherence_results), np.std(coherence_results)



  data = [
    ["PMI", avg_pmi, std_pmi],
    ["NPMI", avg_npmi, std_npmi],
    ["Coherence", avg_coherence, std_coherence],
  ]
  columns = ["Metric", "Avg", "Std"]
  df = pd.DataFrame(data, columns=columns)
  return df

# %%
get_result_table(results)
# Out:
#       Metric         Avg        Std
# 0        PMI   40.855594  35.659783
# 1       NPMI    0.029166   0.020366
# 2  Coherence -255.171205  71.341997

# %% [markdown]
# #Getting metric results

# %% [markdown]
# ##BERTOPIC

# %% [markdown]
# The 1st state-of-the-art model for comparison

# %%
! pip install bertopic

# %%
from bertopic import BERTopic
bt = BERTopic(language="multilingual")
from scipy.sparse import bsr_array
bsr_arraytopics, probs = bt.fit_transform(ds.data)
# Out:
# .gitattributes:   0%|          | 0.00/968 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.09k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# unigram.json:   0%|          | 0.00/14.8M [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
bertopic_topics = bt.get_topic_info()
bertopic_results = bertopic_topics.Representation.tolist()
for i in range(len(bertopic_results)):
    print('Topic', i, ':', ', '.join(bertopic_results[i]))
# Out:
# Topic 0 : the, is, to, of, and, in, for, it, that, from
# Topic 1 : gun, guns, militia, firearms, weapon, weapons, firearm, police, of, you
# Topic 2 : card, drivers, diamond, ati, video, driver, speedstar, vesa, 24x, windows
# Topic 3 : israel, israeli, arab, jews, arabs, israelis, cpr, war, adam, borders
# Topic 4 : 55, hockey, 25, nhl, team, period, 11, 10, pp, play
# Topic 5 : bmw, car, moa, engine, cars, honda, miles, ford, com, qazi
# Topic 6 : sound, audio, stereo, midi, relays, channel, speaker, irq, noise, soundblaster
# Topic 7 : space, nasa, jpl, spacecraft, gov, baalke, kelvin, dealy, ___, gsfc
# Topic 8 : entry, output, file, oname, printf, entries, fprintf, char, contest, stream
# Topic 9 : stephanopoulos, president, mr, we, jobs, clinton, file, myers, congress, that
# Topic 10 : turkish, armenian, armenians, serdar, argic, turks, genocide, soviet, zuma, armenia
# Topic 11 : vs, gm, flyers, game, hawks, blues, ahl, chi, adirondack, at
# Topic 12 : objective, morality, values, frank, christian, dwyer, d012s658, cobb, 2000, mchp
# Topic 13 : printer, ink, deskjet, hp, printers, print, laser, bubblejet, canon, 500
# Topic 14 : batf, fbi, roby, udel, waco, compound, fire, chopin, koresh, they
# Topic 15 : db, mov, bh, si, byte, bl, maxbyte, eff, encryption, di
# Topic 16 : atf, burns, survivors, dividian, ranch, stove, irvine, stratus, fbi, wpi
# Topic 17 : windows, allocation, dos, linked, vpic46, swap, gfx, cross, unit, file
# Topic 18 : jpeg, image, graphics, images, pub, format, gif, ftp, data, 3d
# Topic 19 : islam, jaeger, rushdie, islamic, gregg, bu, muslim, buphy, allah, qur
# Topic 20 : polygon, den, p3, p1, p2, ___, routine, points, radius, op_rows
# Topic 21 : color, colormap, colormaps, colors, visual, window, depth, default, clients, standard
# Topic 22 : key, des, keys, s1, s2, keyseach, bits, machine, chip, nsa
# Topic 23 : cwru, cleveland, po, reserve, ins, freenet, western, oh, ch981, hela
# Topic 24 : drive, disk, boot, hard, drives, switch, floppy, ide, controller, settings
# Topic 25 : christianity, god, christian, why, religion, atheist, we, existence, christians, exists
# Topic 26 : msg, food, sensitivity, chinese, superstition, glutamate, restaurant, dyer, olney, foods
# Topic 27 : hell, god, heaven, eternal, satan, he, believe, jesus, bible, that
# Topic 28 : israel, lebanese, israeli, lebanon, hezbollah, civilians, attacks, hernlem, villages, iran
# Topic 29 : 800, adb, waikato, xv, apple, engin, ku, gre, edu, umich
# Topic 30 : games, sega, genesis, game, arcade, joystick, sale, snes, joysticks, nintendo
# Topic 31 : bible, testament, books, greek, contradictions, word, church, cf, lexicon, god
# Topic 204 : they, were, she, her, he, was, sumgait, apartment, had, we
# Topic 205 : dyer, spdcc, aches, hismanal, astemizole, otc, preparations, sheryl, lrc, analgesics
# Topic 206 : tie, breaker, record, rpi, wangr, win, points, ahve, rex, devils
# Topic 207 : ups, power, switchover, electric, inverter, balls, batteries, dc, poles, battery
# Topic 208 : weight, omen, wa7kgx, forsberg, caf, obesity, diet, chuck, rebound, gordon
# Topic 209 : jb, ron, roth, placebo, gr, medicine, rose, rosemail, rr, mds
# Topic 210 : weaver, cooper, hound, hunting, crphilli, dazixca, qualcomm, knife, prosecution, deer
# Topic 211 : octopus, detroit, ice, dlmqc, zazula, cunyvm, dana, squid, gak, harold
# Topic 212 : crypt, des, privacy, cryptography, key, eff, pub, faq, ciphers, cipher
# Topic 213 : jburnside, cb900c, burnside, behanna, advice, dod, bike, purchase, jamie, ll
# Topic 214 : costly, memorial, museum, holocaust, techbook, jake, mistake, keefe, dangerous, arf
# Topic 215 : gl, pyeatt, texaco, palette_colors, gerard, drawindex, widget, mydisplay, csir, expose
# Topic 216 : station, redesign, option, nasa, space, ssf, connor, tm0006, flights, options
# Topic 217 : 00, wolverine, 1st, 50, hulk, appears, art, comics, cover, sabretooth
# Topic 218 : convex, user, corp, richardson, wagon, expressed, selective, computer, necessarily, tx
# Topic 219 : disk, bios, drives, drive, rom, controller, feature, hard, supports, st506
# Topic 220 : sin, aids, god, sins, forgiven, repent, sinful, infants, original, punishment
# Topic 221 : hades, dartmouth, vram, simms, coos, hanover, moderator, hughes, comics, nh
# Topic 222 : fpu, apple, mouse, c650, dartmouth, brochures, ferch, ergo, utkvx, adb
# Topic 223 : sunrise, sunset, drexel, cbis, wetstein, jpw, times, rouben, ece, pearson
# Topic 224 : pantheism, environmentalism, heath, paganism, uga, watt, terrance, athos, ours, cavano
# Topic 225 : rail, train, texas, speed, unisql, jfh, rpp386, fast, eliot, dude
# Topic 226 : timing, snow, drain, timers, crystal, timer, farad, weeks, ultra, cold

# %%
results = count_metrics(bertopic_results, wf, wfid)
get_result_table(results)
# Out:
#       Metric        Avg        Std
# 0        PMI  20.675695  19.710966
# 1       NPMI   0.114489   0.109385
# 2  Coherence -37.992408  12.051126

# %% [markdown]
# ##Top2Vec

# %% [markdown]
# The 2nd state-of-the-art model for comparison

# %%
from IPython.display import clear_output
# !pip install top2vec
# !pip install top2vec[sentence_transformers]
clear_output()

# %%
# !pip install top2vec[sentence_encoders]
clear_output()

# %%
from top2vec import Top2Vec

# %%
model = Top2Vec(ds.data, embedding_model='universal-sentence-encoder-multilingual')
num_topics = model.get_num_topics()
top2vec_topic_words, top2vec_word_scores, top2vec_topic_nums = model.get_topics(num_topics)
for i in range(len(top2vec_topic_words)):
    print('Topic', i, ':', ', '.join(top2vec_topic_words[i]))
results = count_metrics(top2vec_topic_words, wf, wfid)
get_result_table(results)
# Out:
# 2023-11-19 06:17:57,402 - top2vec - INFO - Pre-processing documents for training
# INFO:top2vec:Pre-processing documents for training
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 2023-11-19 06:18:16,865 - top2vec - INFO - Downloading universal-sentence-encoder-multilingual model
# INFO:top2vec:Downloading universal-sentence-encoder-multilingual model
# 2023-11-19 06:18:32,571 - top2vec - INFO - Creating joint document/word embedding
# INFO:top2vec:Creating joint document/word embedding
# 2023-11-19 06:31:18,203 - top2vec - INFO - Creating lower dimension embedding of documents
# INFO:top2vec:Creating lower dimension embedding of documents
# 2023-11-19 06:32:01,741 - top2vec - INFO - Finding dense areas of documents
# INFO:top2vec:Finding dense areas of documents
# 2023-11-19 06:32:02,077 - top2vec - INFO - Finding topics
# INFO:top2vec:Finding topics
# Topic 0 : phillies, dodgers, yankees, espn, nhl, hockey, pittsburgh, playoffs, playoff, bruins, gretzky, baseball, standings, hawks, pitchers, rangers, rutgers, canucks, teams, cubs, islanders, braves, orioles, goalie, tavares, hopkins, stanford, stanley, brady, team, league, ufl, jersey, phil, cleveland, puck, tim, habs, robinson, coach, eddie, lopez, hitter, lindros, hl, purdue, pitcher, sports, williams, lemieux
# Topic 1 : edu, universities, professor, university, prof, educational, academic, ncsu, wustl, article, subject, decnet, wrote, education, cnn, freenet, newsletter, cited, scholars, nichols, zisfein, contrib, sc_, institute, deleted, uni, literature, publications, doctrine, telnet, students, campus, organizations, dsl, stanford, nc, college, ncsl, stl, topics, publication, srl, ioccc, harvard, subjects, enet, ns, uoknor, msstate, sc
# Topic 2 : spacecraft, aerospace, astronaut, astronomy, satellites, astronomical, planetary, orbiter, satellite, space, orbit, planet, orbital, telescope, edu, rockets, rocket, astro, gravity, sci, moon, atmospheric, propulsion, sciences, scientists, nasa, earth, stl, solar, scientist, funded, ozone, funding, observatory, launches, probes, sphere, galaxy, universe, landing, aircraft, science, jupiter, wustl, exploration, sky, mars, planes, scsi, galileo
# Topic 3 : encryption, encrypted, decrypt, crypt, cryptography, ciphers, ciphertext, cipher, cryptology, cryptographic, crypto, cryptosystem, criminals, algorithms, password, algorithm, obfuscated, governments, bitnet, crimes, govt, keys, key, libertarians, criminal, hacker, telnet, secure, chip, decnet, government, crime, escrow, liberties, patents, security, gov, libertarian, theoretical, privacy, constitutional, patent, enforcement, codes, protocol, constitution, binaries, paranoid, copyright, pirates
# Topic 4 : edu, universities, university, campus, educational, ncsu, stanford, professor, college, prof, academic, institute, education, email, wustl, send, majors, rutgers, nc, ucsu, schools, uni, sending, students, upenn, classes, student, subject, sent, telnet, dsl, doesn, mailing, transmitted, cnn, networking, msstate, teaching, nmsu, teaches, school, univ, zisfein, follows, decnet, umn, sciences, steveh, organizations, organization
# Topic 5 : disease, diseases, physicians, doc, doctor, doctors, homeopathy, physician, medicine, dr, patients, cure, seizures, symptoms, edu, medical, syndrome, docs, infection, zisfein, chronic, kidney, med, treatment, clinical, therapy, pain, std, candida, scientist, patient, hiv, wounded, aids, clinic, suffering, surgery, sick, professor, suffered, glutamate, academic, suffer, sciences, nichols, arts, zoology, prof, quack, ph
# Topic 22 : monitor, monitors, svga, vga, screens, screen, mydisplay, motherboard, psu, macintosh, rgb, ncd, mhz, graphics, pixels, pixel, mac, toshiba, vram, display, rendering, raster, edu, pentium, powerpc, config, warranty, sony, nmsu, displays, macs, xterm, fpu, telnet, desktop, processor, graphic, khz, gamma, window, computers, msu, chz, linux, specs, problem, workstations, workstation, okcforum, windows
# Topic 23 : libxmu, xterm, xlib, unix, x_s, compile, xl, xt, gfx, yx, xdm, ascii, aix, linux, xmu, compiler, xs, csrc, compiled, xview, xfree, gcc, dx, ax, xv, xpert, lib, bxn, gnu, digex, sx, bx, sox, pixmap, zx, thanx, xxdate, kernel, cunixb, cx, acad, nyx, problem, src, solved, docs, cad, libraries, okcforum, tx
# Topic 24 : homosexuals, homosexuality, gays, homosexual, gay, bi, sexual, immoral, libertarians, morals, rape, straight, libertarian, discrimination, morality, edu, males, minorities, minority, partners, moral, universities, victims, atheists, std, society, hiv, sex, consent, men, atheism, boys, republicans, crimes, liberal, liberties, male, marriage, aids, zionism, civil, orientation, msstate, individuals, groups, communities, unc, theology, fbi, laws
# Topic 25 : amp, sold, stereo, selling, sell, speakers, offers, offer, sale, electronics, offered, deals, speaker, pioneer, gibson, audio, price, trade, claimed, pm, sells, sony, deal, radio, sent, purchase, interested, bought, electronic, forsale, purchased, vendor, traded, buy, marshall, edu, setup, edm, received, buying, sound, sending, budget, caltech, cdp, msu, purchasing, inexpensive, up, available
# Topic 26 : jpeg, files, ftp, fprintf, adobe, pixmap, bitmap, file, gif, formats, bmp, software, raster, acad, programs, cad, program, images, format, graphic, printf, windows, pixel, graphics, rendering, quicktime, filename, gcc, docs, gnu, freenet, byte, siggraph, linux, csrc, unix, pixels, binaries, libxmu, bytes, render, vms, gfx, image, ascii, shareware, compile, microsoft, gmt, vga
# Topic 27 : atheism, atheists, atheist, theists, christianity, theology, belief, existence, beliefs, deity, religions, gods, believers, religious, religion, universe, faith, athena, christians, fallacy, skepticism, philosophy, god, allah, doctrine, argument, exists, reasoning, rational, divine, judaism, arguments, creator, secular, exist, teachings, logic, logical, theories, believing, creation, evolution, biblical, reason, genesis, christian, reasons, scripture, eternal, hypothesis
# Topic 28 : windows, memory, vms, ram, linux, motherboard, cmos, bios, ssd, pentium, microsoft, virus, openwindows, cpu, disks, compaq, vm, exe, microsystems, kernel, compuserve, disk, vram, macintosh, unix, files, compile, gb, bytes, okcforum, compiler, mb, norton, vga, msdos, floppy, problem, sys, programs, processor, mhz, gnu, csd, svga, computing, byte, storage, binaries, hardware, cdrom
# Topic 29 : printer, printers, deskjet, printing, print, printed, printf, ink, scanner, compaq, pixmap, cartridge, paper, canon, publications, hp, compuserve, powerbook, pentium, posters, poster, mailer, fprintf, papers, publication, adobe, raster, computers, copies, acad, writes, machine, pascal, laser, copy, dpi, mail, software, machines, output, jpeg, postscript, processor, pens, document, computer, office, newspaper, pixel, mailing
# Topic 47 : christianity, biblical, christians, judaism, scripture, jews, jewish, bible, testament, atheists, christian, scriptures, commandments, israelis, messiah, israeli, theists, teachings, atheism, atheist, prophets, religion, jew, jesus, religions, israel, religious, palestinians, theology, prophecy, sins, orthodox, holocaust, genocide, verses, schism, doctrine, churches, believers, prophet, zionism, jerusalem, salvation, deity, hebrew, judas, righteous, beliefs, palestinian, gospel
# Topic 48 : pixmap, colormap, bitmap, pixel, xterm, unix, xview, libxmu, pixels, gfx, rendering, mapping, rgb, x_s, digex, cx, graphics, raster, dx, csrc, xpert, bxn, aix, ascii, xdm, render, tcp, xlib, jpeg, yx, paint, fprintf, kernel, graphic, resolution, bx, printf, xt, gcc, cview, ax, acad, xv, nyx, sx, compile, zx, xl, compiler, vga
# Topic 49 : mouse, cursor, caltech, motherboard, netcom, linux, windows, pentium, microsystems, compaq, cmos, hardware, svga, kernel, commands, vms, edu, microsoft, psu, software, command, vga, dpi, computers, powerpc, intel, cpu, rat, bios, joystick, controllers, ctrl, ports, comm, fpu, qt, controller, irq, openwindows, ics, unix, wpi, computer, computing, desk, macintosh, informatik, iq, magnus, problem
# Topic 50 : pentium, mac, macs, powerpc, macintosh, cpu, fpu, powerbook, linux, processor, motherboard, edu, intel, psu, apple, phillies, universities, vga, svga, caltech, lciii, kernel, config, university, pcs, education, chip, computers, libxmu, informatik, hardware, computing, educational, phil, toshiba, ucsc, cmos, bios, ncsu, pc, iii, wrote, oac, college, specs, mhz, philadelphia, ibm, cunixb, ram
# Topic 51 : window, windows, openwindows, okcforum, dialog, interface, ctrl, xterm, cursor, widget, cadre, frame, xview, screen, widgets, screens, intervention, interactive, srl, fprintf, unix, rendering, xdm, desktop, open, processes, pointer, mydisplay, panel, opened, mouse, bureau, monitor, processing, useragent, layout, domain, script, cview, dev, motherboard, applications, functionality, microsoft, office, external, implementation, handler, pixmap, quicktime
# Topic 52 : motherboard, pentium, svga, cpu, vga, cmos, ram, processor, psu, intel, powerpc, bios, pcs, microsystems, fpu, vram, hardware, pc, computers, config, linux, upgrade, mhz, computer, compaq, compuserve, toshiba, pm, specs, ssd, macintosh, electronics, dsl, vms, sys, integrated, boards, ethernet, budget, microsoft, modems, speedstar, computing, khz, chz, module, workstations, workstation, array, maxtor
# Topic 53 : widget, xterm, widgets, xview, cview, pointer, libxmu, gcc, pointers, unix, compile, interface, cursor, gfx, xlib, fprintf, csrc, compiler, xt, colormap, ascii, window, yx, windows, function, okcforum, program, kernel, printf, x_s, ics, pixmap, functionality, mydisplay, cad, algorithm, references, xpert, raster, functions, nyx, xl, algorithms, linux, digex, qt, packet, rendering, applications, ncd
# Topic 54 : catholics, catholic, priests, doctrine, biblical, pope, scripture, theology, christianity, scriptures, priest, churches, teachings, church, christians, religious, mary, bishop, orthodox, atheism, disciples, religion, sins, bible, gospel, nuntius, believers, religions, christian, messiah, commandments, atheists, atheist, theists, jesus, skepticism, saint, beliefs, secular, chapel, schism, worship, faith, spiritual, judaism, passages, sin, testament, deity, trinity
# Topic 55 : windows, linux, microsoft, openwindows, pentium, macintosh, telnet, window, mac, microsystems, binaries, freenet, compaq, unix, kernel, processor, macs, computing, netnews, gnu, toshiba, vms, ftp, software, shareware, informatik, processes, programs, computers, compuserve, files, bitnet, powerpc, motherboard, disks, desktop, okcforum, docs, cpu, msdos, edu, workstations, decnet, cmos, interface, usenet, txt, nsa, disk, uunet
# Topic 56 : modems, modem, telnet, ethernet, telecom, netcom, module, dsl, bps, edu, speedstar, netnews, gateway, pentium, universities, freenet, mode, modes, university, bandwidth, internet, ftp, usenet, vms, linux, fashion, comm, bitnet, mac, speeds, mx, motherboard, campus, steveh, upgrade, kernel, computers, packet, decnet, informatik, academic, dc, macintosh, sending, education, send, computer, nmsu, transmission, networking
# Topic 57 : cds, cd, sale, sell, sold, edm, sells, selling, deals, edu, cdc, purchased, records, jackson, ups, sales, buying, deal, buy, pm, purchase, collection, offers, cdp, copies, releases, nubus, forsale, collect, purchasing, interested, bought, nyi, nichols, funded, bands, mj, offered, funding, price, trade, stuff, prices, universities, offer, lincoln, craig, stevens, tm, dsl
# Topic 58 : cds, cdrom, cd, disks, disk, stereo, disc, macintosh, cdc, macs, cdp, mac, audio, pioneer, ncd, speakers, sony, toshiba, linux, ssd, apple, kernel, msu, cmos, acsu, shareware, unix, edu, cdt, sdsu, drives, oac, jsc, csd, isc, lciii, speaker, aix, kpc, iii, sound, motherboard, cornell, amp, computers, noise, microsystems, boot, drivers, hardware
# Topic 59 : helmet, jacket, motorcycle, harley, bike, gear, motorcycles, bikes, riding, protect, protecting, leather, har, protection, wear, belt, covered, safety, wearing, suit, motor, rider, uniform, handgun, head, slip, bag, rear, riders, harvey, ride, protected, covering, xx, replies, safe, header, rubber, covers, pocket, skndiv, insurance, spare, cover, cap, neck, dsl, socket, heads, hi
# Topic 60 : ssd, disks, disk, cmos, scsi, vms, csd, cdrom, ethernet, sdsu, drives, motherboard, svga, sc_, bsd, bios, sc, pentium, hardware, stl, cds, csc, floppy, jsc, sequences, cdc, intel, vga, linux, kernel, decnet, spdcc, macintosh, cd, maxtor, bps, dsp, ncd, cpu, vm, unix, catbyte, telnet, cables, toshiba, compuserve, drivers, ansi, hd, byte
# Topic 61 : hp, compaq, harry, hewlett, printer, powerbook, harley, hcf, houston, tcp, compuserve, powerpc, har, ottawa, ups, harris, harvey, printers, hst, uucp, wp, hartford, page, gsfc, spdcc, powered, halifax, sps, txt, cp, fl, hq, covington, follows, pages, deskjet, res, hl, repair, fc, computer, upenn, wustl, rfc, power, hi, wd, falls, phone, watt
# Topic 62 : games, controllers, controller, sell, genesis, sold, trade, game, joystick, selling, offers, traded, wwii, sale, gt, sells, mario, offer, deals, offered, ups, deal, interested, steam, mwm, svga, up, ds, pm, forsale, sales, vga, mw, claimed, dsl, condition, references, electronics, craig, handheld, throw, shipping, need, sony, funded, play, caltech, config, fpu, sent
# Topic 71 : rgb, colormap, jpeg, pixel, bitmap, pixmap, pixels, colors, graphics, rendering, raster, images, paint, vga, svga, graphic, colour, color, ncd, image, converter, gif, algorithms, siggraph, adobe, ascii, fprintf, render, bmp, acad, imaging, resolution, program, contrast, cad, gamma, gcc, printf, programs, kernel, byte, formats, colorado, vms, algorithm, cryptography, software, gb, gfx, computing
# Topic 72 : photography, images, imaging, edu, objects, scientist, photo, scientists, optical, pictures, astronomy, educational, science, exposure, object, image, academic, sciences, professor, scientific, electronics, subject, camera, subjects, proton, prof, nichols, zoology, universities, telescope, shots, physics, scholars, education, picture, pixmap, knowledge, canon, fields, electronic, theories, teaches, light, molecular, pixels, lab, taught, prism, studied, einstein
# Topic 73 : toyota, car, auto, automobile, automotive, bmw, cars, autos, vw, mileage, vehicle, honda, sold, wagon, ford, vehicles, dealer, garage, truck, selling, speedstar, sale, sell, transmission, offers, condition, deals, warranty, interested, offer, dealers, stratus, engine, references, motor, driven, engines, drove, wheels, price, deal, parking, offered, mechanical, sales, tires, steering, forsale, pm, drive
# Topic 74 : insurance, hospitals, diseases, republicans, physicians, medical, libertarians, doctors, disease, libertarian, edu, doc, wounded, docs, patients, coverage, dr, physician, limbaugh, hospital, free, liberal, policies, welfare, taxes, medicine, care, doctor, surgery, programs, seizures, clinic, health, govt, costs, conservative, std, expense, deficit, funded, treated, treatment, cure, injuries, aid, policy, bill, hiv, vnews, benefits
# Topic 75 : edu, nyc, campus, illinois, universities, apartment, rent, tickets, stanford, deals, chicago, offers, hcf, ticket, email, rutgers, aerospace, university, education, ohio, college, hawaii, utilities, student, ny, wisconsin, ncsu, philadelphia, telecom, northeastern, inexpensive, cincinnati, academic, offer, york, ucsu, harvard, room, wustl, interested, baltimore, houston, applied, educational, prof, house, pm, funding, fsu, ucla
# Topic 76 : trinity, jesus, christianity, doctrine, scripture, biblical, christians, teachings, theology, scriptures, theists, deity, spiritual, catholics, religions, disciples, christian, catholic, messiah, atheism, atheist, religion, atheists, religious, sins, bible, salvation, divine, believers, beliefs, prophets, allah, commandments, joshua, testament, prophet, judaism, gods, belief, gospel, cult, worship, sin, priests, spirit, faith, secular, eternal, righteous, orthodox
# Topic 77 : fonts, font, fprintf, plaintext, type, truetype, formats, ascii, windows, printf, typing, letters, ctrl, types, format, acad, adobe, text, raster, srl, characters, printer, window, print, postscript, letter, cad, width, compaq, printing, polytechnic, printed, printers, script, txt, versions, jpeg, literature, ftp, graphic, dpi, writings, siggraph, roman, cursor, romans, source, ciphertext, kinds, wrote
# Topic 78 : telephone, tel, telecom, calls, telnet, call, number, phones, calling, phone, numbers, callison, dial, cellular, lines, line, operator, rogers, texts, handy, illinois, ericsson, dsl, linear, gps, trace, ncsl, neal, cell, sector, called, bell, row, required, sequence, signal, mobile, needed, txt, wire, text, serial, prof, string, wiring, requires, edu, hi, array, hasn
